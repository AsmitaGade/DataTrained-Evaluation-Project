# %%
# I have used Decsion tree and XG booSTING METHOD

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv('baseball.csv')
ds
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df=pd.DataFrame(ds)
df(head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2904/3994569506.py in <module>
#       1 df=pd.DataFrame(ds)
# ----> 2 df(head)
#
# NameError: name 'head' is not defined

# %%
df.info

# %%
df.sample(3)

# %%
df.shape
# Out:
# (30, 17)

# %%
df.keys()
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# Checking Null values in dataset

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Observations: There is no Null valies in this dataset. so we can proceed further

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df.W.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64>

# %%
df.drop_duplicates()
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# Data Visualization

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df['W'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['R'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['AB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['H'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['2B'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['3B'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['HR'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['BB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SO'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SB'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['RA'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['ER'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['ERA'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SHO'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SV'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['E'].plot.box()
# Out:
# <AxesSubplot:>

# %%
# Observation: there are some outliers are present in columns such as "R","ERA", "SHO", "SV" AND "E"

# %%
df.plot(kind='box', subplots=True, layout=(2,18), figsize=(18,18))
# Out:
# W         AxesSubplot(0.125,0.536818;0.036215x0.343182)
# R      AxesSubplot(0.168458,0.536818;0.036215x0.343182)
# AB     AxesSubplot(0.211916,0.536818;0.036215x0.343182)
# H      AxesSubplot(0.255374,0.536818;0.036215x0.343182)
# 2B     AxesSubplot(0.298832,0.536818;0.036215x0.343182)
# 3B      AxesSubplot(0.34229,0.536818;0.036215x0.343182)
# HR     AxesSubplot(0.385748,0.536818;0.036215x0.343182)
# BB     AxesSubplot(0.429206,0.536818;0.036215x0.343182)
# SO     AxesSubplot(0.472664,0.536818;0.036215x0.343182)
# SB     AxesSubplot(0.516121,0.536818;0.036215x0.343182)
# RA     AxesSubplot(0.559579,0.536818;0.036215x0.343182)
# ER     AxesSubplot(0.603037,0.536818;0.036215x0.343182)
# ERA    AxesSubplot(0.646495,0.536818;0.036215x0.343182)
# CG     AxesSubplot(0.689953,0.536818;0.036215x0.343182)
# SHO    AxesSubplot(0.733411,0.536818;0.036215x0.343182)
# SV     AxesSubplot(0.776869,0.536818;0.036215x0.343182)
# E      AxesSubplot(0.820327,0.536818;0.036215x0.343182)
# ...

# %%
# Bivariate analysis with the output variable

# %%
plt.scatter(df['W'], df['R'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['AB'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['H'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['2B'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['3B'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['HR'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['BB'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['SO'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['SB'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['RA'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['ER'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['ERA'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['CG'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['SHO'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['SV'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df['W'], df['E'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df)

# %%
# Observations:
#1. There are no Null Vlaues in this dataset.
#2. There are some Outliers present so we have to remove them by suitable methods
#3.There is no need to do label encoding

# %% [markdown]
# Removing Outliers with the method USING ZSCORE

# %%
from scipy.stats import zscore

# %%
zscore(df)
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299
# 1   0.197838  0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967
# 2   0.003243 -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377
# 3  -0.483244 -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181
# 4  -0.677839  0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770
# 5   1.170814  3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047
# 6   0.587028  1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833
# 7   0.003243  0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636
# 8  -0.094054 -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601
# 9  -0.288649  1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163
# 10  0.684326  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125
# ...

# %%
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
# Total rows of dataloss

len(np.where(z>3)[0])
# Out:
# 1

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
print('Old DataFrame', df.shape)
print('New DataFrame', df.shape)
print('Total_Dropped_Rows', df.shape[0] - df_new.shape[0])
# Out:
# Old DataFrame (30, 17)
# New DataFrame (30, 17)
# Total_Dropped_Rows 1

# %%
print(df.shape)
print(df_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
# Observation : Only 1 row has been deleted from the Datset

# %%
# Check Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
plt.figure(figsize=(18,18))
sns.heatmap(df.corr(),cmap= 'YlOrRd_r', linewidth=0.5, annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
# Write observation
1. positive corraltion
2.Negative correlation
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_2904/707354683.py", line 2
#     1. positive corraltion
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Summary statistics

# %%
df.describe()
round(df.describe()[1:].transpose(),2)
# Out:
#         mean     std      min      25%      50%      75%      max
# W      80.97   10.45    63.00    74.00    81.00    87.75   100.00
# R     688.23   58.76   573.00   651.25   689.00   718.25   891.00
# AB   5516.27   70.47  5385.00  5464.00  5510.00  5570.00  5649.00
# H    1403.53   57.14  1324.00  1363.00  1382.50  1451.50  1515.00
# 2B    274.73   18.10   236.00   262.25   275.50   288.75   308.00
# 3B     31.30   10.45    13.00    23.00    31.00    39.00    49.00
# HR    163.63   31.82   100.00   140.25   158.50   177.00   232.00
# BB    469.10   57.05   375.00   428.25   473.00   501.25   570.00
# SO   1248.20  103.76   973.00  1157.50  1261.50  1311.50  1518.00
# SB     83.50   22.82    44.00    69.00    83.50    96.50   134.00
# RA    688.23   72.11   525.00   636.25   695.50   732.50   844.00
# ER    635.83   70.14   478.00   587.25   644.50   679.25   799.00
# ERA     3.96    0.45     2.94     3.68     4.03     4.22     5.04
# ...

# %%
plt.figure(figsize=(18,18))
sns.heatmap(round(df.describe()[1:].transpose(),2), linewidth=2, annot=True, fmt='')
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)
plt.title('Variable summary')
plt.show()

# %%
# Observations from the above corrlation heatmap

# %%
# Check Skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
# Lets check Noral distribution curve

# %%
sns.distplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.distplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(df['HR'])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(df['BB'])
# Out:
# <AxesSubplot:xlabel='BB', ylabel='Density'>

# %%
sns.distplot(df['SO'])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(df['SB'])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(df['RA'])
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %%
sns.distplot(df['ER'])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
# This dataset has some skewnsess present so we have to balance it. for thatwe have to seperate the variables from the Traget/output column

# %%
# separate the dataset x and y

# %%
# independent variables

x=df_new.iloc[:,1:]
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# ...

# %%
# Target

y=df_new.iloc[:,0]
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
df_new.shape
# Out:
# (29, 17)

# %%
# Transfroming data to remove skewness

# %%
import sklearn
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method="yeo-johnson")

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([[ 9.62569268e-01,  8.46359883e-01,  1.67721130e+00,
#          1.70501701e+00,  1.00821401e+00, -7.38549418e-01,
#         -1.59342078e+00, -2.52265498e+00,  9.35987706e-01,
#         -6.63484666e-01, -5.14012705e-01, -5.15054785e-01,
#         -3.18537586e-01, -7.88486538e-01,  1.52534194e+00,
#         -3.31781664e-01],
#        [ 2.97395258e-01, -6.80208684e-01, -8.59086447e-01,
#          1.27251302e-01,  1.19389204e+00, -1.00567628e-01,
#         -4.68097231e-01,  8.78305820e-02, -5.19237207e-01,
#          1.55288423e-01,  2.27703331e-01,  2.33598678e-01,
#         -3.18537586e-01,  2.31783673e-01,  3.16899471e-01,
#         -5.28394725e-01],
#        [-3.13561320e-01, -1.11833737e+00, -5.64605770e-02,
#          1.93455938e+00, -2.45242549e-01, -6.59841866e-01,
#          1.23669865e+00, -9.35493526e-01,  2.21102515e-01,
#         -6.77371069e-01, -7.55231078e-01, -6.46399265e-01,
#          2.04586091e+00, -2.57732765e-01, -6.61517926e-01,
#         -1.34309958e+00],
# ...

# %%
x.ndim
# Out:
# 2

# %%
x.mean()
# Out:
# -4.785444071660157e-19

# %%
# check if data is standardised

x.std()
# Out:
# 1.0

# %%
# Observation: std deviation is 1 means the data is standardized

# %% [markdown]
# Balance this dataset

# %%
x=df_new.iloc[:,1:]
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# ...

# %%
y=df_new.iloc[:,0]
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
y.value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 97     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 95     1
# 98     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 79     1
# Name: W, dtype: int64

# %%
y.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  87,  80,  78,  88,  86,  85,  68, 100,
#         98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='W', ylabel='count'>

# %%
# w

# %%
x=df_new.iloc[:,1:]
x.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
y=df_new.iloc[:,0]
y.head()
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %% [markdown]
# # Model Building
#
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression


from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=.20, random_state=42)

# %%
x_train.shape
# Out:
# (23, 16)

# %%
x_test.shape
# Out:
# (6, 16)

# %%
y_train.shape
# Out:
# (23,)

# %%
y_test.shape
# Out:
# (6,)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 7.66636257e-02, -1.03191981e-01,  7.94637593e-02,  4.51239680e-02,
#         1.25354979e-01,  4.72357761e-02, -2.97181789e-02, -1.24160455e-02,
#        -1.13956740e-01, -2.40133975e-02,  1.09551217e+00, -1.84976550e+02,
#        -1.79995631e-01, -3.19890073e-01, -4.70401179e-02, -1.45822267e-02])

# %%
lm.intercept_
# Out:
# 559.6841263296602

# %%
lm.score(x_train, y_train)
# Out:
# 0.9669863192160296

# %%
# predict the value

pred=lm.predict(x_test)
print('Predicted win:', pred)
print('Acutal win', y_test)
# Out:
# Predicted win: [74.44532015 80.38120321 79.05585402 58.71294186 80.20180823 79.70002275]
# Acutal win 28    74
# 17    97
# 13    76
# 23    67
# 9     78
# 10    88
# Name: W, dtype: int64

# %%
print('error:')

print('Mean absolute error:', mean_absolute_error(y_test,pred))
print('Mean Sqaured error:', mean_squared_error,(y_test, pred))

print('Root mean squared error:', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# Mean absolute error: 6.484802428856227
# Mean Sqaured error: <function mean_squared_error at 0x0000013A8C294790> (28    74
# 17    97
# 13    76
# 23    67
# 9     78
# 10    88
# Name: W, dtype: int64, array([74.44532015, 80.38120321, 79.05585402, 58.71294186, 80.20180823,
#        79.70002275]))
# Root mean squared error: 8.44722710776669

# %%
# r2 score: coefficient of determination

from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.25928395352745615

# %%
# predict the win by providing the values

t=np.array([669,5439,1395,303,29,141,533,1157,86,640,584,3.67,11,10,38,79])

# %%
t.shape
# Out:
# (16,)

# %%
t=t.reshape(1,-1)
t.shape
# Out:
# (1, 16)

# %%
lm.predict(t)
# Out:
# array([81.95374111])

# %%
df=pd.DataFrame(pred)
df.to_csv('baseball_win_pred_submission.csv')

# %%
# Cross- Validation of the model

# %%
from sklearn.model_selection import cross_val_score

score=cross_val_score(lm,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [ 0.7557458  -0.67830114  0.66816769 -0.25396453 -0.30350451]
# 0.0376286604965234
# 0.570477976644125

# %%
# prediction

# %%
import numpy as np
s=np.array([622,5533,1381,260,27,136,404,1231,68,701,643,3.98,7,9,37,101])
s
# Out:
# array([6.220e+02, 5.533e+03, 1.381e+03, 2.600e+02, 2.700e+01, 1.360e+02,
#        4.040e+02, 1.231e+03, 6.800e+01, 7.010e+02, 6.430e+02, 3.980e+00,
#        7.000e+00, 9.000e+00, 3.700e+01, 1.010e+02])

# %%
s.shape
# Out:
# (16,)

# %%
s=s.reshape(1,-1)

# %%
s.shape
# Out:
# (1, 16)

# %%
predwin=lm.predict(s)
predwin
# Out:
# array([76.67064563])

# %%
# saving the prediction with cross-validation

# %%
dft=pd.DataFrame(predwin)
dft.to_csv('prediction_lm.csv')

# %%
# saving the model using pickle

import pickle

filename='picklelmfile.pkl'
pickle.dump(lm,open(filename, 'wb'))

# load the model from the disk

loaded_model=pickle.load(open(filename, 'rb'))
loaded_model.predict(x_test)
# Out:
# array([74.44532015, 80.38120321, 79.05585402, 58.71294186, 80.20180823,
#        79.70002275])
