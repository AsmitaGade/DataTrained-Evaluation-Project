# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_excel("avocado.xlsx")
ds
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
ds.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
ds1=ds.drop(['Date'], axis=1)

# %%
ds1
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type  year  \
# ...

# %%
df=pd.DataFrame(ds1)
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5677.40      133.76          0.0  conventional  2015  Albany
# 4     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.sample(3)
# Out:
#        AveragePrice  Total Volume       4046       4225      4770  Total Bags  \
# 13662          2.47       5578.01    1536.63    3147.80      0.00      893.58
# 13729          1.47       5885.34     690.44     177.87     32.19     4984.84
# 2195           1.58     564456.60  106180.64  351965.39  33512.19    72798.38
#
#        Small Bags  Large Bags  XLarge Bags          type  year         region
# 13662      843.36       50.22          0.0       organic  2016  PhoenixTucson
# 13729     4905.79       79.05          0.0       organic  2016     Pittsburgh
# 2195     72030.82      735.56         32.0  conventional  2015   SanFrancisco

# %%
df.tail(3)
# Out:
#        AveragePrice  Total Volume     4046     4225    4770  Total Bags  \
# 18246          1.87      13766.76  1191.92  2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63  2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77  2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags     type  year            region
# 18246     9351.80       42.31          0.0  organic  2018  WestTexNewMexico
# 18247    10919.54       50.00          0.0  organic  2018  WestTexNewMexico
# 18248    11988.14       26.01          0.0  organic  2018  WestTexNewMexico

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
# check missing values

df.isnull().sum()
# Out:
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Observation : This dataset has no Null values

# %%
df['AveragePrice'].describe()
# Out:
# count    18249.000000
# mean         1.405978
# std          0.402677
# min          0.440000
# 25%          1.100000
# 50%          1.370000
# 75%          1.660000
# max          3.250000
# Name: AveragePrice, dtype: float64

# %%
df['region'].describe()
# Out:
# count      18249
# unique        54
# top       Albany
# freq         338
# Name: region, dtype: object

# %%
sns.distplot(df['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %% [markdown]
# Data Visualization

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume',           4046,           4225,
#                  4770,   'Total Bags',   'Small Bags',   'Large Bags',
#         'XLarge Bags',         'type',         'year',       'region'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#         AveragePrice  Total Volume          4046          4225          4770  \
# count   18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std         0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min         0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%         1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%         1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%         1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max         3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
# ...

# %%
df.type.unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
df.year.unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
df.region.unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
# Data Visualization

# %%
# we have two types of avacado : organic and conventional. we have to check type vs average price 

sns.boxplot(y='type', x='AveragePrice', data=df, palette='Blues')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='type'>

# %%
# observtaion: converntional fruit price is more compared to conventonal

# %%
sns.boxplot(x='region',y='AveragePrice',data=df, palette='Blues')
# Out:
# <AxesSubplot:xlabel='region', ylabel='AveragePrice'>

# %%
df['Total Volume'].plot.box()
# Out:
# <AxesSubplot:>

# %%
# plotting histogram for plot for all the columns.



df.hist(figsize=(20,20), grid=True, layout=(4,4), bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>,
#         <AxesSubplot:title={'center':'4225'}>],
#        [<AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>,
#         <AxesSubplot:title={'center':'Small Bags'}>,
#         <AxesSubplot:title={'center':'Large Bags'}>],
#        [<AxesSubplot:title={'center':'XLarge Bags'}>,
#         <AxesSubplot:title={'center':'year'}>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
# Check Correlation

df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.093197
# ...

# %%
df.corr()['AveragePrice'].sort_values()
# Out:
# 4046           -0.208317
# Total Volume   -0.192752
# 4770           -0.179446
# Total Bags     -0.177088
# Small Bags     -0.174730
# Large Bags     -0.172940
# 4225           -0.172928
# XLarge Bags    -0.117592
# year            0.093197
# AveragePrice    1.000000
# Name: AveragePrice, dtype: float64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(ds.corr(),cmap= 'YlOrRd_r', linewidth=0.5, annot=True, fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
# Label Encoder for object columns: type and region variables

# one hot encoder is for binary values(0 and 1). it is also used for True/false

# Label encoder is for values which are (>2) like(0,1,2,3 etc)

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

list=['region', 'type']
for val in list:
    df[val]=le.fit_transform(df[val].astype(str))
    
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %%
df.describe()
round(df.describe()[1:].transpose(),2)
# Out:
#                    mean         std      min       25%        50%        75%  \
# AveragePrice       1.41        0.40     0.44      1.10       1.37       1.66
# Total Volume  850644.01  3453545.36    84.56  10838.58  107376.76  432962.29
# 4046          293008.42  1264989.08     0.00    854.07    8645.30  111020.20
# 4225          295154.57  1204120.40     0.00   3008.78   29061.02  150206.86
# 4770           22839.74   107464.07     0.00      0.00     184.99    6243.42
# Total Bags    239639.20   986242.40     0.00   5088.64   39743.83  110783.37
# Small Bags    182194.69   746178.51     0.00   2849.42   26362.82   83337.67
# Large Bags     54338.09   243965.96     0.00    127.47    2647.71   22029.25
# XLarge Bags     3106.43    17692.89     0.00      0.00       0.00     132.50
# type               0.50        0.50     0.00      0.00       0.00       1.00
# year            2016.15        0.94  2015.00   2015.00    2016.00    2017.00
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
# ...

# %%
# Correlation of all columns

collist=['AveragePrice', 'type', 'region', 'Total Volume', 'Total Bags', 'year']
dfcorr1= np.corrcoef(df[collist].values.T)
sns.set(font_scale=1.7)

hm=sns.heatmap(dfcorr1, cbar= True, annot = True,square = True, fmt = '.2f', annot_kws = {'size':15}, yticklabels = collist, xticklabels = collist)

# %% [markdown]
#  Observation: as we can see there is a strong correlation between Averageprice and type
#  ,as well as between Total volume and total bags
#
# in some column there is weak or negative correlation between Large abgs ans total volume
#
#  only some features are correlated with the Average price but most of the features corralted with each other.

# %%
df['region'].nunique()
# Out:
# 54

# %%
df['type'].nunique()
# Out:
# 2

# %%
# describe column plot

import matplotlib.pyplot as plt
plt.figure(figsize=(15,15))
sns.heatmap(round(ds.describe()[1:].transpose(),2), linewidth=2, annot=True, fmt='f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('Variables summary')
plt.savefig('heatmap.png')
plt.show()

# %%
# observations

# %%
# Check Skewness of the dataset

df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %%
# Normal distribution curve

# %%
sns.distplot(df['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(df['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(df['Total Bags'])
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
sns.distplot(df['Small Bags'])
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='Density'>

# %%
sns.distplot(df['Large Bags'])
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='Density'>

# %%
sns.distplot(df['type'])
# Out:
# <AxesSubplot:xlabel='type', ylabel='Density'>

# %%
sns.distplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.distplot(df['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='Density'>

# %%
sns.distplot(df[4046])
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Density'>

# %%
sns.distplot(df[4225])
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Density'>

# %%
sns.distplot(df[4770])
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Density'>

# %%
# Observation:the nrmal deistribution curve has shown that data is liittle skewed

# %%
# Removing Outliers

# %%
from scipy.stats import zscore

# %%
zscore(df)
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0         -0.188689     -0.227716 -0.230816 -0.199902 -0.212091   -0.234170
# 1         -0.139020     -0.230427 -0.231103 -0.208054 -0.211997   -0.233350
# 2         -1.182069     -0.212085 -0.231007 -0.154478 -0.211325   -0.234730
# 3         -0.809551     -0.223444 -0.230741 -0.185350 -0.211864   -0.237096
# 4         -0.312861     -0.231538 -0.230891 -0.208719 -0.211834   -0.236718
# ...             ...           ...       ...       ...       ...         ...
# 18244      0.556347     -0.241373 -0.230017 -0.243857 -0.212540   -0.229301
# 18245      0.755023     -0.242296 -0.230693 -0.242277 -0.212540   -0.233594
# 18246      1.152375     -0.242331 -0.230693 -0.243090 -0.205766   -0.233463
# 18247      1.301382     -0.241625 -0.230428 -0.242651 -0.205774   -0.231866
# 18248      0.531512     -0.241253 -0.229347 -0.243170 -0.210450   -0.230807
#
# ...

# %%
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (18249, 12)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
np.where(z>3)
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64),
#  array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
# percentage data loss

loss_percent=(18249-1773)/18249*100
print(loss_percent, '%')
# Out:
# 90.28439914515863 %

# %%
# Observation: we can not just delete so many rows , so we wil use Standard scaler or power transform

# %% [markdown]
# Seperate the Data

# %%
# independent variable

x=df.iloc[:,1:]
x
# Out:
#        Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0          64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1          54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2         118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3          78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4          51039.60   941.48   43838.39   75.78     6183.95     5986.26
# ...             ...      ...        ...     ...         ...         ...
# 18244      17074.83  2046.96    1529.20    0.00    13498.67    13066.82
# 18245      13888.04  1191.70    3431.50    0.00     9264.84     8940.04
# 18246      13766.76  1191.92    2452.79  727.94     9394.11     9351.80
# 18247      16205.22  1527.63    2981.04  727.01    10969.54    10919.54
# 18248      17489.58  2894.77    2356.13  224.53    12014.15    11988.14
#
#        Large Bags  XLarge Bags  type  year  region
# 0           93.25          0.0     0  2015       0
# ...

# %%
# Target

y=df.iloc[:,0]
y
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
x.shape
# Out:
# (18249, 11)

# %%
y.shape
# Out:
# (18249,)

# %%
# Transforming data to remove skewness

# %%
import sklearn

from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method="yeo-johnson")

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.ndim
# Out:
# 2

# %%
x.mean()
# Out:
# -1.459229633095688e-06

# %%
# check if data is standardized

x.std()
# Out:
# 1.0000000000106468

# %% [markdown]
# Observation : data is standardized

# %%
# Model Building: Linear Regresion

# %%
#first we will try using Linear regression to predict the Average price of avacados

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume',           4046,           4225,
#                  4770,   'Total Bags',   'Small Bags',   'Large Bags',
#         'XLarge Bags',         'type',         'year',       'region'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.20, random_state=42)

# %%
x=df.iloc[:,1:]

y=df.iloc[:,0]


print('x train shape', x_train.shape)
print('y train shape', y_train.shape)

print('x test shape', x_test.shape)
print('y test shape', y_test.shape)
# Out:
# x train shape (14599, 11)
# y train shape (14599,)
# x test shape (3650, 11)
# y test shape (3650,)

# %%
# Creating and training Linear Regression model

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test,pred))
print('MSE:', metrics.mean_squared_error(y_test,pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# MAE: 0.2176104205279325
# MSE: 0.0787479501220075
# RMSE: 0.28062065163135713

# %%
# lets plot it

plt.scatter(x=y_test, y=pred)

# %%
# observation: RMSE is low so we can say it is good model
# we can also see from the plot that it is not exactlt a straight line. so we can check decison tree model also to be sore

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)

# %%
plt.scatter(x=y_test, y=pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
# Observation: Here we can see from the plot that we are getting somewhat straihjt line

# %%
print('MAE:', metrics.mean_absolute_error(y_test,pred))
print('MSE:', metrics.mean_squared_error(y_test,pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# MAE: 0.14521917808219176
# MSE: 0.04986030136986301
# RMSE: 0.22329420361904384

# %%
# observation : here we are geeting even low rmse from linear which is good fro our model, so now we have to try to imrove predictions using random forest regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
pred=rfr.predict(x_test)

# %%
print('MAE:', metrics.mean_absolute_error(y_test,pred))
print('MSE:', metrics.mean_squared_error(y_test,pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# MAE: 0.10964249315068494
# MSE: 0.02425421586575342
# RMSE: 0.1557376507648469

# %%
# Observation: as we can see here we are getting low rmse from previous two models.
# so we can go with the Randomforestregressor.

# %%
sns.distplot((y_test-pred), bins=50)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
# we are getting normal distributed curve. which is good for us to go ahead.

# %%
data =pd.DataFrame({'Y Test':y_test , 'Pred':pred},columns=['Y Test','Pred'])
sns.lmplot(x='Y Test',y='Pred',data=data,palette='rainbow')
data.head()
# Out:
#        Y Test    Pred
# 8604     0.82  1.0334
# 2608     0.97  0.9882
# 14581    1.44  1.4330
# 4254     0.97  0.9242
# 16588    1.45  1.4588

# %%
dfpr=pd.DataFrame(pred)
dfpr.to_csv('prediction_rfr.csv')

# %%
# Save the best model using pickle method

import pickle

filename='picklerfrfile.pkl'
pickle.dump(rfr,open(filename, 'wb'))


# load the model from the disk

loaded_model=pickle.load(open(filename, 'rb'))
loaded_model.predict(x_test)
# Out:
# array([1.0334, 0.9882, 1.433 , ..., 0.5912, 1.6445, 2.2548])

# %% [markdown]
# # Conclusion:RandomForestRegressor is the best model here.
# 2. I understood through analysis that low RMSE score can help us to undestand the better model
# 3. I undestood about preprocessing of the data and feature engineering
